# %% [markdown]
# <a href="https://colab.research.google.com/github/Spyke2022/BookRepo/blob/master/IPOG_Series_temporais_aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução às Séries Temporais
#
# Uma série temporal é um conjunto
# de observações ordenadas, 𝒙𝒕
# cada uma registrada num tempo
# específico t, resultante de um
# comportamento que pode ser
# representado por um modelo
# matemático.
#
#
# ### Finanças e Economia
#
# - **Previsão de Preços de Ativos:** Utilização de séries temporais para prever movimentos futuros no preço de ações, títulos ou commodities.
# - **Análise de Risco:** Estimativa da volatilidade do mercado e outros riscos financeiros baseada em dados históricos.
# - **Modelagem de Investimentos:** Otimização de portfólios através da previsão de correlações e retornos esperados de diferentes ativos.

# %% [markdown]
# ## Aplicações das Séries Temporais
#
# Séries temporais são usadas em diversos campos, como economia, meteorologia, engenharia e ciências sociais. Algumas aplicações incluem:
#
# ### Saúde
#
# - **Epidemiologia:** Monitoramento e previsão da propagação de doenças. Séries temporais são usadas para acompanhar o número de casos ao longo do tempo e ajudar na tomada de decisões de saúde pública.
# - **Monitoramento de Pacientes:** Coleta de dados em tempo real, como frequência cardíaca e pressão arterial, para previsão de eventos adversos em pacientes.
#
# ### Engenharia e Tecnologia
#
# - **Controle de Processos:** Em ambientes industriais, séries temporais são utilizadas para monitorar e ajustar processos de produção para manter a qualidade e eficiência.
# - **Sistemas de Recomendação:** Algoritmos que usam dados de interações passadas para prever futuras preferências e comportamentos de usuários.
#
# ### Ciências Sociais e Ambientais
#
# - **Estudos Climáticos:** Análise de tendências de longo prazo em dados climáticos para entender mudanças climáticas e suas implicações.
# - **Pesquisa Demográfica:** Análise de mudanças na população, como crescimento ou migração, para planejamento de recursos e infraestrutura.
#
# ### Segurança e Monitoramento
#
# - **Detecção de Anomalias:** Uso de séries temporais para identificar comportamentos ou eventos não típicos, como fraudes em transações bancárias ou falhas em sistemas de segurança.
# - **Vigilância de Tráfego:** Monitoramento e análise do fluxo de veículos em estradas ou redes urbanas para otimização do tráfego e planejamento de rotas.
#
#
# ## Principais Pontos Sobre a Importância e Complexidade das Previsões
#
# ### Importância das Previsões
# - **Diversas Aplicações:** Desde a construção de instalações de geração de energia até a programação de pessoal em call centers e gestão de inventário.
#
# - **Vários Horizontes Temporais:** Previsões podem ser necessárias para planejamentos de longo prazo (como investimentos de capital) ou para necessidades imediatas (como roteamento de telecomunicações).
#
# ### Fatores que Influenciam a Precisão das Previsões
# - **Compreensão dos Fatores Contribuintes:** Quanto melhor entendemos o que afeta uma variável, mais precisas podem ser nossas previsões.
# - **Disponibilidade de Dados:** A abundância de dados históricos melhora a confiabilidade das previsões.
# - **Similaridade com o Passado:** Previsões são mais precisas quando o futuro se assemelha ao comportamento passado.
# - **Impacto das Previsões:** Em alguns casos, previsões podem influenciar o evento que está sendo previsto, alterando os resultados.
#
#
# ### Exemplos de Previsibilidade
# - **Demanda de Eletricidade Residencial:** Altamente previsível devido à compreensão clara dos fatores, disponibilidade de dados e comportamentos passados semelhantes.
#
# - **Taxas de Câmbio:** Difícil de prever devido à complexidade dos fatores e ao potencial de mudanças rápidas, como crises financeiras ou políticas.
#
# ### Hipótese do Mercado Eficiente
# - **Previsões Autorrealizáveis:** Previsões bem divulgadas podem influenciar o mercado, ajustando-se a si mesmas.
#
# ### Horizonte de Previsão
# - **Definição:** O horizonte de previsão refere-se ao período futuro para o qual a previsão é feita. Pode variar de minutos a anos, dependendo do contexto e da necessidade.
# - **Importância:** Escolher o horizonte de previsão adequado é crucial, pois afeta o tipo de dados e o método de previsão a serem utilizados.
#
#
# ### Métodos de Previsão
# - **Métodos Simples:** Como o método naíve, que usa a observação mais recente como previsão.
# - **Métodos Lineares:** ARIMA, ETS, entre outros modelos estatisticos.
# - **Métodos Não Lineares** Algoritmos de Aprendizado de Máquina, por exemplo MLP, LSTM, Decision Tree, SVR.
#
#
# ### Influência do Horizonte de Previsão na Precisão dos Modelos
#
# - **Incerteza Acumulada:**
#   - Previsões para períodos mais longos acumulam mais incertezas.
#   - Maior dependência de suposições sobre condições futuras e interações variáveis.
#
# - **Disponibilidade e Relevância de Dados:**
#   - Previsões de curto prazo usam dados recentes que são mais relevantes e precisos.
#   - Longos horizontes podem necessitar de dados históricos que podem não refletir mudanças recentes.
#
# - **Estabilidade do Sistema:**
#   - Sistemas estáveis permitem previsões mais precisas mesmo para longos horizontes.
#   - Sistemas dinâmicos são mais desafiadores para prever com precisão à medida que o horizonte se expande.
#
# - **Efeitos de Feedback:**
#   - Previsões podem influenciar os resultados, especialmente em economia e finanças.
#   - Efeitos de feedback são difíceis de modelar e prever para horizontes longos.
#
# - **Mudanças Estruturais e Crises:**
#   - Longos horizontes aumentam a probabilidade de mudanças estruturais e crises.
#   - Tais eventos podem invalidar padrões passados, afetando a precisão das previsões.
#
# - **Complexidade do Modelo:**
#   - Modelos eficazes para curto prazo podem não ser adequados para longos horizontes.
#   - Previsões de longo prazo frequentemente requerem técnicas mais complexas e consideração de fatores exógenos.

# %% [markdown]
# # Análise da Série temporal

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
path = 'https://github.com/EraylsonGaldino/MaterialTS/blob/master/vendas_varejo.xlsx?raw=true'
serie_varejo = pd.read_excel(path)

# %%
serie_varejo.set_index('Data', inplace=True)

# %%
serie_varejo.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Data'>

# %%
btc_symbol = 'BTC-USD'
btc_data = yf.download(btc_symbol, start='2015-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
btc_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01    320.434998    320.434998    314.002991    314.248993
# 2015-01-02    314.079010    315.838989    313.565002    315.032013
# 2015-01-03    314.846008    315.149994    281.082001    281.082001
# 2015-01-04    281.145996    287.230011    257.612000    264.195007
# 2015-01-05    265.084015    278.341003    265.084015    274.473999
# ...                  ...           ...           ...           ...
# 2023-12-27  42518.468750  43683.160156  42167.582031  43442.855469
# 2023-12-28  43468.199219  43804.781250  42318.550781  42627.855469
# 2023-12-29  42614.644531  43124.324219  41424.062500  42099.402344
# 2023-12-30  42091.753906  42584.125000  41556.226562  42156.902344
# 2023-12-31  42152.097656  42860.937500  41998.253906  42265.187500
#
#                Adj Close       Volume
# Date
# 2015-01-01    314.248993      8036550
# 2015-01-02    315.032013      7860650
# ...

# %%
serie_btc_close = btc_data['Adj Close']

# %%
btc_close_month = serie_btc_close.resample('M').sum()

# %%
btc_close_month.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Estacionariedade

# %%
m_m = serie_varejo.rolling(window=12).mean()
m_std = serie_varejo.rolling(window=12).std()

plt.figure(figsize=(10, 5))
orig = plt.plot(serie_varejo, color='blue',label='Original')
mean = plt.plot(m_m, color='red',label='Média')
std = plt.plot(m_std, color='black',label='Desvio')
plt.legend(loc='best')
plt.show()

# %%
m_m = btc_close_month.rolling(window=12).mean()
m_std = btc_close_month.rolling(window=12).std()

plt.figure(figsize=(10, 5))
orig = plt.plot(btc_close_month, color='blue',label='Original')
mean = plt.plot(m_m, color='red',label='Média')
std = plt.plot(m_std, color='black',label='Desvio')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Teste de Dickey-Fuller Aumentado
#
# - **Hipótese Nula (H0):** A série temporal possui uma raiz unitária, indicando que não é estacionária.
# - **Hipótese Alternativa (HA):** A série temporal é estacionária, ou seja, não possui uma raiz unitária.
#
# O teste usa o **valor p** para determinar a rejeição da hipótese nula. Se o valor p for menor que o nível de significância, geralmente 0.05, a hipótese nula é rejeitada, indicando que a série é estacionária.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
dftest = adfuller(serie_varejo)

# %%
nivel_significancia = 0.05
if dftest[1] > nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# A série não é estacionária

# %%
dftest = adfuller(btc_close_month)
print(f'p-value {dftest[1]}')
if dftest[1] > nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# p-value 0.5082791146510536
# A série não é estacionária

# %% [markdown]
# ##### Diferenciação

# %%
serie_varejo_diff = serie_varejo.diff().dropna()

# %%
serie_varejo_diff.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Data'>

# %%
dftest = adfuller(serie_varejo_diff)
print(f'p-value {dftest[1]}')
if dftest[1] > nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# p-value 0.7957924414770232
# A série não é estacionária

# %%
serie_varejo_2_diff = serie_varejo_diff.diff().dropna()
serie_varejo_2_diff.plot()
# Out:
# <Axes: xlabel='Data'>

# %%
dftest = adfuller(serie_varejo_2_diff)
print(f'p-value {dftest[1]}')
if dftest[1] > nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# p-value 2.3972760344014613e-27
# A série é estacionária

# %% [markdown]
# #### Tendência

# %% [markdown]
# ##### Teste de Kwiatkowski-Phillips-Schmidt-Shin (KPSS)
#
# - **Hipótese Nula (H0):** A série temporal é estacionária em torno de uma média ou tendência linear.
# - **Interpretação:** No teste KPSS, buscamos evidências para rejeitar a hipótese nula. Um valor p pequeno (por exemplo, menor que 0.05) indica a rejeição da hipótese nula, sugerindo que a série temporal não é estacionária.
#
# Este teste é útil para verificar se uma série temporal é estacionária em torno de uma tendência, ao contrário do teste de Dickey-Fuller Aumentado, que foca na presença de uma raiz unitária indicando não estacionariedade.

# %%
from statsmodels.tsa.stattools import kpss

# %%
p_value = kpss(serie_varejo)[1]
print(f'p-value {p_value}')
if p_value < nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# p-value 0.01
# A série não é estacionária

# %%
p_value = kpss(btc_close_month)[1]
print(f'p-value {p_value}')
if p_value < nivel_significancia:
  print('A série não é estacionária')
else:
  print('A série é estacionária')
# Out:
# p-value 0.01
# A série não é estacionária

# %% [markdown]
# #### Homocedasticidade

# %% [markdown]
# ##### Teste de Levene
#
# - **Hipótese Nula (H0):** As variâncias entre os grupos são iguais, indicando homocedasticidade.
# - **Interpretação:** O teste de Levene utiliza o valor p para determinar a rejeição da hipótese nula. Se o valor p for menor que o nível de significância, geralmente estabelecido em 0.05, a hipótese nula é rejeitada. Esta rejeição sugere a presença de heterocedasticidade entre os grupos, indicando que as variâncias não são iguais entre eles.

# %%
from scipy import stats
import numpy as np

# %%
groups = np.array_split(serie_varejo, 4)

# %%
groups
# Out:
# [            Indice
#  Data
#  2000-01-01    53.2
#  2000-02-01    53.8
#  2000-03-01    56.1
#  2000-04-01    56.1
#  2000-05-01    58.4
#  2000-06-01    55.6
#  2000-07-01    57.6
#  2000-08-01    57.4
#  2000-09-01    56.0
#  2000-10-01    57.1
#  2000-11-01    58.1
#  2000-12-01    80.1
#  2001-01-01    54.2
#  2001-02-01    51.1
#  2001-03-01    57.5
#  2001-04-01    55.0
#  2001-05-01    57.1
#  2001-06-01    54.9
#  2001-07-01    55.2
#  2001-08-01    56.7
#  2001-09-01    54.4
#  2001-10-01    57.8
#  2001-11-01    56.7
#  2001-12-01    77.9
#  2002-01-01    53.6
#  2002-02-01    50.3
#  2002-03-01    57.7
#  2002-04-01    53.9
#  2002-05-01    57.8
#  2002-06-01    53.9
#  2002-07-01    56.2
#  2002-08-01    58.0
#  2002-09-01    53.6
#  2002-10-01    58.1
#  2002-11-01    56.7
#  2002-12-01    73.9
#  2003-01-01    51.2
#  2003-02-01    49.5
#  2003-03-01    51.1
#  2003-04-01    51.9
#  2003-05-01    54.2
#  2003-06-01    50.8
#  2003-07-01    53.7
#  2003-08-01    54.7
# ...

# %%
def levene_test(serie, qtd_groups):
    groups = np.array_split(serie, qtd_groups)
    st, p_value = stats.levene(*groups)
    print(f'p_value: {p_value}')
    if p_value > nivel_significancia:
      print('As variâncias são iguais')
    else:
      print('As variâncias são diferentes')

# %%
 levene_test(serie_varejo['Indice'].values, 20)
# Out:
# p_value: 0.9844518390729139
# As variâncias são iguais

# %%
levene_test(btc_close_month.values, 10)
# Out:
# p_value: 1.4141054961752604e-13
# As variâncias são diferentes

# %% [markdown]
# #### Sazonalidade

# %%
m_m = serie_varejo.rolling(window=3).mean()
plt.figure(figsize=(10, 5))
orig = plt.plot(serie_varejo, color='blue',label='Original')
mean = plt.plot(m_m, color='red',label='Média')
plt.legend(loc='best')
plt.show()

# %%
m_m = btc_close_month.rolling(window=3).mean()
plt.figure(figsize=(10, 5))
orig = plt.plot(btc_close_month, color='blue',label='Original')
mean = plt.plot(m_m, color='red',label='Média')
plt.legend(loc='best')
plt.show()

# %%
anos = serie_varejo.index.year.unique()


for ano in anos:
    df_ano = serie_varejo[serie_varejo.index.year == ano]
    plt.plot(df_ano.index.month, df_ano['Indice'], label=str(ano))

plt.title('Série Temporal Ano a Ano')
plt.xlabel('Mês do Ano')
plt.ylabel('Valor')
plt.legend(title='Ano')
plt.grid(True)

# %% [markdown]
# #### Decomposição

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(serie_varejo['Indice'])
result.plot();

# %%
result

# %% [markdown]
# ##### Autocorrelação

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,3))

plot_acf(serie_varejo, lags=36, ax=ax[0]);
plot_pacf(serie_varejo, lags=36, ax=ax[1]);

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,3))

plot_acf(btc_close_month, lags=36, ax=ax[0]);
plot_pacf(btc_close_month, lags=36, ax=ax[1]);

# %% [markdown]
# #Atividade 01:
# Escolha 2 séries temporais:
#  * descreva quais os comportamentos em cada série.
#  * é possível utilizar o passado para prever o futuro de cada série temporal?
